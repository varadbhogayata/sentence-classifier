# %% [markdown]
# ## Sentence Classification
#
# ### Why not Deep-learning:
#     We have very small amount of data and LSTMs are not good with small amount of data, Hence need to use Linear Classifier
#
# ### Steps:
# 1. Preprocessing
#     * Create one csv file which stores all files(particularly all rows from each file) from **labeled_articles** folder (__PreprocessedCSV.csv__ will be generated after executing cell[1] contaning all rows
#     * To remove __####Abstract__ and __####Introduction__ from original text files, convert csv file to pandas dataframe and remove those rows using pandas
#     * Remove whitespace from the column **label** as some of the columns contain 'OWNX' and 'OWNX ', therefore consider this as two different classes.
#     * Cleaning the data by using regex
#     * Collect stopwords from stopwords.txt file given in the data and store it in **stopword list** (Later will be used as input parameter to CountVectorizer)
#
# 2. Tfidf features followed by SVM multiclass classification(oneVsOther)
#     * Store sentences data from pandas dataframe to __X__ and labels to __y__ and convert them to numpy vectors
#     * Split data into training and testing with 80:20 ratio and set any random seed value so that we can produce the same result with exact same accuracy and weights
#     * Create a model having pipeline of CountVectorizer, TfidfTransformer, LinearSVC functions
#     * Perform GridSearch to find optimum parameter for training the data
#     * Provide the optimum parameter and train the model
#     * Plot Confusion matrix and accuracy score
#     * Save the model so that it can be used directly again on this dataset
#     * Test the model with inputing any sentence given from any files of **unlabeled_articles** folder

# %%
import csv
import glob
import pandas as pd

#create one csv file which will store all sentences with appropriate tags
csv_file = "E:/STUDY/Placements/dishQ/SentenceCorpus/labeled_articles/preprocessedCSV.csv"  
path = "E:/STUDY/Placements/dishQ/SentenceCorpus/labeled_articles/*.txt"    # path of all txt files
files=glob.glob(path)  

# add all data of txt data into single csv file
for f in files:
    with open(f, "r") as in_text:
        in_reader = csv.reader(in_text, delimiter = '\t')
        with open(csv_file, "a") as out_csv:
            out_writer = csv.writer(out_csv)
            for row in in_reader:
                out_writer.writerow(row)

# %%
# give title to dataframe
title = ['label', 'sentence']
df = pd.read_csv(csv_file,sep=',',header=None,names=title)   # dataframe 
df.rename(columns=lambda x: x.strip())    # remove whitespace from column names
df['label'] = df['label'].str.strip()     # 'OWNX' and 'OWNX ' two diff classes
df = df.dropna()                          # drop the rows where Sentence value is NaN (remove ##intro, ##abstract which is present in txt file)
with pd.option_context('display.max_rows', None, 'display.max_columns', 5):
    print(df)

#print(df)
#df.to_csv('E:/STUDY/Placements/dishQ/SentenceCorpus/labeled_articles/newFile.csv',sep=',')
#df.columns
# Out:
#      label                                           sentence
# 1     MISC  The Minimum Description Length principle for o...
# 2     MISC  If the underlying model class is discrete, the...
# 3     MISC  For MDL, in general one can only have loss bou...
# 4     AIMX  We show that this is even the case if the mode...
# 5     OWNX  We derive a new upper bound on the prediction ...
# 6     OWNX  This implies a small bound (comparable to the ...
# 7     OWNX  We discuss the application to Machine Learning...
# 9     MISC  ``Bayes mixture", ``Solomonoff induction", ``m...
# 10    CONT  In many cases however, the Bayes mixture is co...
# 11    MISC  The MDL or MAP (maximum a posteriori) estimato...
# 12    MISC  In practice, the MDL estimator is usually bein...
# 13    MISC  How good are the predictions by Bayes mixtures...
# 14    MISC         This question has attracted much attention
# 15    MISC  In many cases, an important quality measure is...
# 16    MISC  In particular the square loss is often considered
# 17    MISC  Assume that the outcome space is finite, and t...
# 18    MISC  Then for Bayes mixture prediction, the cumulat...
# 19    MISC  This corresponds to an  instantaneous  loss bo...
# 20    MISC  For the MDL predictor, the losses behave simil...
# 21    MISC  Note that in order to do MDL for continuous mo...
# 22    MISC  On the other hand, if the model class is discr...
# 23    MISC  The only necessary assumption is that the true...
# 24    MISC  It has been demonstrated  CITATION , that for ...
# 25    MISC  For MDL predictions in the proper learning cas...
# 26    MISC  This bound is exponentially larger than the So...
# 27    MISC  A finite bound on the total expected square lo...
# 28    MISC  In contrast, an instantaneous loss bound of  S...
# 29    MISC  Additionally, it gives a  convergence speed , ...
# 30    MISC  So for both, Bayes mixtures and MDL, convergen...
# 31    MISC  We avoid the term ``convergence rate" here, si...
# 32    MISC  It is eg  SYMBOL  if we additionally assume th...
# 33    MISC  It is therefore natural to ask if there are mo...
# 34    AIMX  In the present work, we concentrate on the sim...
# 35    OWNX  Note that then the MDL ``predictor" just becom...
# 36    OWNX  Nevertheless, for consistency of terminology, ...
# 37    MISC  It might be surprising to discover that in gen...
# 38    OWNX  On the other hand, we will give mild condition...
# 39    MISC  Moreover, it is well-known that the instantane...
# 40    MISC             The same holds for MDL, as we will see
# 41    MISC  If convergence speed is measured in terms of i...
# 42    MISC  A particular motivation to consider discrete m...
# 43    MISC  From a computational point of view, the larges...
# 44    MISC  Thus each model corresponds to a program, and ...
# 45    MISC  Moreover, the models are stochastic, precisely...
# 46    MISC  Each model has a natural description length, n...
# 47    MISC  If we agree that programs are binary strings, ...
# 48    MISC  By the Kraft inequality, the priors sum up to ...
# 49    MISC  Also the Bernoulli case can be studied in the ...
# 50    MISC  We call this the  universal setup : Given a un...
# 51    MISC  The description length  SYMBOL  of a parameter...
# 52    MISC      A prior weight may then be defined by  SYMBOL
# 53    MISC  If a string  SYMBOL  is generated by a Bernoul...
# 54    MISC  That is, the two-part complexity with respect ...
# 55    MISC  Many Machine Learning tasks are or can be redu...
# 56    MISC             An important example is classification
# 57    MISC  The task of classifying a new instance  SYMBOL...
# 58    MISC       Typically the (instance,class) pairs are iid
# 59    MISC  Cumulative loss bounds for prediction usually ...
# 60    MISC  Then we can solve classification problems in t...
# 61    OWNX  It is not obvious if and how the proofs in thi...
# 62    OWNX  Our main tool for obtaining results is the Kul...
# 63    OWNX    Lemmata for this quantity are stated in Section
# 64    OWNX  Section  shows that the exponential error boun...
# 65    OWNX  In Section , we give an upper bound on the ins...
# 66    OWNX  The latter bound is small eg under certain con...
# 67    OWNX                Section  treats the universal setup
# 68    OWNX  Finally, in Section  we discuss the results an...
# 70    MISC  The Minimum Description Length principle for o...
# 71    MISC  If the underlying model class is discrete, the...
# 72    MISC  For MDL, in general one can only have loss bou...
# 73    AIMX  We show that this is even the case if the mode...
# 74    OWNX  We derive a new upper bound on the prediction ...
# 75    OWNX  This implies a small bound (comparable to the ...
# 76    OWNX  We discuss the application to Machine Learning...
# 78    MISC  ``Bayes mixture", ``Solomonoff induction", ``m...
# 79    CONT  In many cases however, the Bayes mixture is co...
# 80    MISC  The MDL or MAP (maximum a posteriori) estimato...
# 81    MISC  In practice, the MDL estimator is usually bein...
# 82    MISC  How good are the predictions by Bayes mixtures...
# 83    MISC         This question has attracted much attention
# 84    MISC  In many cases, an important quality measure is...
# 85    MISC  In particular the square loss is often considered
# 86    MISC  Assume that the outcome space is finite, and t...
# 87    MISC  Then for Bayes mixture prediction, the cumulat...
# 88    MISC  This corresponds to an  instantaneous  loss bo...
# 89    MISC  For the MDL predictor, the losses behave simil...
# 90    MISC  Note that in order to do MDL for continuous mo...
# 91    MISC  On the other hand, if the model class is discr...
# 92    MISC  The only necessary assumption is that the true...
# 93    MISC  It has been demonstrated  CITATION , that for ...
# 94    MISC  For MDL predictions in the proper learning cas...
# 95    MISC  This bound is exponentially larger than the So...
# 96    MISC  A finite bound on the total expected square lo...
# 97    MISC  In contrast, an instantaneous loss bound of  S...
# 98    MISC  Additionally, it gives a  convergence speed , ...
# 99    MISC  So for both, Bayes mixtures and MDL, convergen...
# 100   MISC  We avoid the term ``convergence rate" here, si...
# 101   MISC  It is eg  SYMBOL  if we additionally assume th...
# 102   MISC  It is therefore natural to ask if there are mo...
# 103   AIMX  In the present work, we concentrate on the sim...
# 104   OWNX  Note that then the MDL ``predictor" just becom...
# 105   OWNX  Nevertheless, for consistency of terminology, ...
# 106   OWNX  It might be surprising to discover that in gen...
# 107   OWNX  On the other hand, we will give mild condition...
# 108   MISC  Moreover, it is well-known that the instantane...
# 109   MISC             The same holds for MDL, as we will see
# 110   MISC  If convergence speed is measured in terms of i...
# 111   MISC  A particular motivation to consider discrete m...
# 112   MISC  From a computational point of view, the larges...
# 113   MISC  Thus each model corresponds to a program, and ...
# 114   MISC  Moreover, the models are stochastic, precisely...
# 115   MISC  Each model has a natural description length, n...
# 116   MISC  If we agree that programs are binary strings, ...
# 117   MISC  By the Kraft inequality, the priors sum up to ...
# 118   MISC  Also the Bernoulli case can be studied in the ...
# 119   MISC  We call this the  universal setup : Given a un...
# 120   MISC  The description length  SYMBOL  of a parameter...
# 121   MISC      A prior weight may then be defined by  SYMBOL
# 122   MISC  If a string  SYMBOL  is generated by a Bernoul...
# 123   MISC  That is, the two-part complexity with respect ...
# 124   MISC  Many Machine Learning tasks are or can be redu...
# 125   MISC             An important example is classification
# 126   MISC  The task of classifying a new instance  SYMBOL...
# 127   MISC       Typically the (instance,class) pairs are iid
# 128   MISC  Cumulative loss bounds for prediction usually ...
# 129   MISC  Then we can solve classification problems in t...
# 130   OWNX  It is not obvious if and how the proofs in thi...
# 131   OWNX  Our main tool for obtaining results is the Kul...
# 132   OWNX    Lemmata for this quantity are stated in Section
# 133   OWNX  Section  shows that the exponential error boun...
# 134   OWNX  In Section , we give an upper bound on the ins...
# 135   OWNX  The latter bound is small eg under certain con...
# 136   OWNX                Section  treats the universal setup
# 137   OWNX  Finally, in Section  we discuss the results an...
# 208   MISC  although the internet as level topology has be...
# 209   MISC  an as  node  can represent a wide variety of o...
# 210   AIMX  in this paper  we introduce a radically new ap...
# 211   OWNX  we successfully classify  NUMBER   NUMBER  per...
# 212   OWNX  we release to the community the as level topol...
# 213   OWNX  we believe that this dataset will serve as an ...
# 215   MISC  the rapid expansion of the internet in the las...
# 216   MISC  from  NUMBER  to  NUMBER  the number of global...
# 217   MISC  this impressive growth has resulted in a heter...
# 218   MISC  in particular  the as level topology is an int...
# 219   MISC  statistical information that faithfully charac...
# 220   MISC  in topology modeling  knowledge of as types is...
# 221   MISC  for example  we expect the network of a dual h...
# 222   MISC  the university will likely contain dozens of i...
# 223   MISC  on the other hand  the small company will most...
# 224   MISC  since there is such a diversity among differen...
# 225   MISC  moreover  annotating the ases in the as topolo...
# 226   MISC  for example  internet service providers  isp  ...
# 227   MISC  on the other hand  small companies that connec...
# 228   MISC  thus  categorizing different types of ases in ...
# 229   MISC  an as taxonomy is also necessary for mapping i...
# 230   MISC  for example  in traffic analysis studies its o...
# 231   MISC  given an as taxonomy  its possible to realize ...
# 232   AIMX  in this work  we introduce a radically new app...
# 233   OWNX  we develop an algorithm to classify ases based...
# 234   OWNX  we use a large set of data from the internet r...
# 235   AIMX  then  we employ a novel machine learning techn...
# 236   OWNX  we derive macroscopic statistics on the differ...
# 237   OWNX  our validation demonstrates that our classific...
# 238   OWNX  finally  we make our results and our classifie...
# 239   OWNX  in section  we start with a brief discussion o...
# 240   OWNX  section  describes the data we used  and in se...
# 241   OWNX  section  introduces our classification approac...
# 242   OWNX  we validate them in section  and conclude in s...
# 244   MISC  although the internet as level topology has be...
# 245   MISC  an as  node  can represent a wide variety of o...
# 246   AIMX  in this paper  we introduce a radically new ap...
# 247   OWNX  we successfully classify  NUMBER   NUMBER  per...
# 248   OWNX  we release to the community the as level topol...
# 249   OWNX  we believe that this dataset will serve as an ...
# 251   MISC  the rapid expansion of the internet in the las...
# 252   MISC  from  NUMBER  to  NUMBER  the number of global...
# 253   MISC  this impressive growth has resulted in a heter...
# 254   MISC  in particular  the as level topology is an int...
# 255   MISC  statistical information that faithfully charac...
# 256   MISC  in topology modeling  knowledge of as types is...
# 257   MISC  for example  we expect the network of a dual h...
# 258   MISC  the university will likely contain dozens of i...
# 259   MISC  on the other hand  the small company will most...
# 260   MISC  since there is such a diversity among differen...
# 261   MISC  moreover  annotating the ases in the as topolo...
# 262   MISC  for example  internet service providers  isp  ...
# 263   MISC  on the other hand  small companies that connec...
# 264   MISC  thus  categorizing different types of ases in ...
# 265   MISC  an as taxonomy is also necessary for mapping i...
# 266   MISC  for example  in traffic analysis studies its o...
# 267   MISC  given an as taxonomy  its possible to realize ...
# 268   AIMX  in this work  we introduce a radically new app...
# 269   AIMX  we develop an algorithm to classify ases based...
# 270   OWNX  we use a large set of data from the internet r...
# 271   OWNX  then  we employ a novel machine learning techn...
# 272   OWNX  we derive macroscopic statistics on the differ...
# 273   OWNX  our validation demonstrates that our classific...
# 274   OWNX  finally  we make our results and our classifie...
# 275   BASE  in section  we start with a brief discussion o...
# 276   OWNX  section  describes the data we used  and in se...
# 277   OWNX  section  introduces our classification approac...
# 278   OWNX  we validate them in section  and conclude in s...
# 316   AIMX  in this paper we derive the equations for loop...
# 317   OWNX  using the exactness of the averages for belief...
# 318   OWNX  we discuss the relation of this  loop correcti...
# 320   MISC  message passing techniques in graphical models...
# 321   MISC  their discovery has consequently revolutionize...
# 322   MISC  in many cases  the corresponding graphs are lo...
# 323   MISC  in other cases  more sophisticated refinements...
# 324   MISC  finding the optimal treatment of these   loop ...
# 325   MISC  for models involving many short loops   like o...
# 326   MISC  the latter may also be  applied to correct for...
# 327   MISC  unifying frameworks like the region graphs of ...
# 328   MISC  a recent analysis has shown that the local upd...
# 329   MISC  these quantities are parameterizations of the ...
# 330   MISC  the bethe approximation and bp are recovered w...
# 331   MISC  estimation of these pair cumulants is possible...
# 332   MISC  although this scaling seems heavy  the large b...
# 333   MISC  the above   loop correction    strategy is app...
# 334   MISC  the principal requirement  is that the magnitu...
# 335   MISC  however  heuristics based on the strategy allo...
# 336   CONT  so far the approach has been developed for dis...
# 337   AIMX  in this paper we apply the idea to graphical m...
# 338   OWNX  we derive the loop corrected belief propagatio...
# 339   OWNX  besides that we discuss some approaches potent...
# 340   CONT  a by product of our loop corrected belief prop...
# 394   MISC  defensive forecasting is a method of transform...
# 395   MISC  there are two known varieties of defensive for...
# 396   AIMX  this note shows that the randomized variety ca...
# 397   CONT  textbf new as compared to version  NUMBER    N...
# 398   CONT  in the case where   is finite  it is shown tha...
# 400   MISC  the continuous variety of defensive forecastin...
# 401   CONT  the randomized variety was introduced  in the ...
# 402   CONT  non asymptotic versions of the randomized vari...
# 403   BASE  kakade and foster  CITATION  noticed that some...
# 404   AIMX  this note states two simple results about defe...
# 405   OWNX  the proof of theorem  is obtained from the pro...
# 406   OWNX  in our informal discussions we will be assumin...
# 407   OWNX  the reader who is only interested in the main ...
# 409   MISC  defensive forecasting is a method of transform...
# 410   MISC  there are two known varieties of defensive for...
# 411   MISC  this note shows that the randomized variety ca...
# 412   OWNX  new as compared to version  NUMBER    NUMBER  ...
# 413   OWNX  in the case where   is finite  it is shown tha...
# 415   MISC  the continuous variety of defensive forecastin...
# 416   MISC  the randomized variety was introduced  in the ...
# 417   MISC  non asymptotic versions of the randomized vari...
# 418   BASE  kakade and foster  CITATION  noticed that some...
# 419   AIMX  this note states two simple results about defe...
# 420   OWNX  the proof of theorem  is obtained from the pro...
# 421   AIMX  in our informal discussions we will be assumin...
# 422   OWNX  the reader who is only interested in the main ...
# 439   CONT  most generalization bounds in learning theory ...
# 440   CONT  in contrast  the notion of algorithmic stabili...
# 441   CONT  however  as in much of learning theory  existi...
# 442   CONT  in many machine learning applications  however...
# 443   CONT  the observations received by the learning algo...
# 444   AIMX  this paper studies the scenario where the obse...
# 445   OWNX  we prove novel and distinct stability based ge...
# 446   BASE  these bounds strictly generalize the bounds gi...
# 447   OWNX  we also illustrate the application of our   mi...
# 448   OWNX  these novel bounds can thus be viewed as the f...
# 450   CONT  most generalization bounds in learning theory ...
# 451   CONT  these measures characterize a class of hypothe...
# 452   CONT  in contrast  the notion of algorithmic stabili...
# 453   CONT  a learning algorithm is stable if the hypothes...
# 454   CONT  algorithmic stability has been used effectivel...
# 455   CONT  but  as in much of learning theory  existing s...
# 456   CONT  in many machine learning applications  this as...
# 457   CONT  the observations received by the learning algo...
# 458   CONT  this is clear in system diagnosis or time seri...
# 459   CONT  clearly  prices of different stocks on the sam...
# 460   CONT  but  a less apparent time dependency may affec...
# 461   AIMX  this paper studies the scenario where the obse...
# 462   OWNX  we prove novel and distinct stability based ge...
# 463   BASE  these bounds strictly generalize the bounds gi...
# 464   BASE  our proofs are based on the independent block ...
# 465   CONT  however  our analysis differs from previous us...
# 466   BASE  for our analysis of stationary   mixing sequen...
# 467   BASE  this leads to stability based generalization b...
# 468   OWNX  our generalization bounds for stationary   mix...
# 469   OWNX  we also illustrate the application of our   mi...
# 470   CONT  algorithms such as support vector regression  ...
# 471   CONT  to our knowledge  the use of these algorithms ...
# 472   CONT  the stability bounds we give for svr  svms  an...
# 473   OWNX    the following sections are organized as follows
# 474   OWNX  in section   we introduce the necessary defini...
# 475   OWNX  section  gives our main generalization bounds ...
# 476   OWNX  finally  section  presents the first known sta...
# 556   AIMX  this paper studies quantum annealing  qa  for ...
# 557   OWNX  we derive a qa algorithm for clustering and pr...
# 558   CONT  experiments show the proposed qa algorithm fin...
# 559   CONT      furthermore  qa is as easy as sa to implement
# 561   MISC  clustering is one of the most popular methods ...
# 562   MISC  typically  clustering problems are formulated ...
# 563   MISC           however  clustering is typically np hard
# 564   MISC  the simulated annealing  sa   CITATION  is a p...
# 565   MISC  CITATION  proved sa was able to find the globa...
# 566   CONT  although their schedule is in practice too slo...
# 567   CONT  in statistical mechanics  quantum annealing  q...
# 568   CONT  qa adds another dimension     to sa for anneal...
# 569   BASE         thus  it can be seen as an extension of sa
# 570   MISC  qa has succeeded in specific problems  e g the...
# 571   OWNX  we do not actually think qa intuitively helps ...
# 572   MISC  a derived qa algorithm depends on the definiti...
# 573   OWNX  we propose quantum effect    which leads to a ...
# 574   AIMX  our contribution is 1) to propose a qa based o...
# 575   OWNX  we also show the proposed algorithm is as easy...
# 576   OWNX  the algorithm we propose is a markov chain mon...
# 577   OWNX  as we explain later  a naive qa sampler is int...
# 578   OWNX  thus  we approximate qa by the suzuki trotter ...
# 579   OWNX  qa st looks like parallel   sas with interacti...
# 580   OWNX  at the beginning of the annealing process  qa ...
# 581   OWNX  hence  qa st finds    local  optima independently
# 582   OWNX  as the annealing process continues  interactio...
# 583   OWNX  qa st at the end picks up the state with the l...
# 584   OWNX  qa st with the proposed quantum effect   works...
# 585   OWNX  fig is an example where data points are groupe...
# 586   OWNX  SYMBOL and SYMBOL are locally optimal and   is...
# 587   OWNX  suppose SYMBOL is equal to two and SYMBOL and ...
# 588   OWNX  although   and   are local optima  the interac...
# 589   OWNX  quantum effect   defines the distance metric o...
# 590   OWNX  in this case  the proposed   locates   between...
# 591   OWNX  thus  the interaction   gives good chance to g...
# 592   OWNX  the proposed algorithm actually finds   from  ...
# 593   OWNX                             fig is just an example
# 594   MISC  however  a similar situation often occurs in c...
# 595   MISC  clustering algorithms in most cases give   alm...
# 596   MISC  thus  a better clustering assignment can be co...
# 597   MISC  note an assignment constructed in such a way i...
# 599   AIMX  This paper studies quantum annealing (QA) for ...
# 600   AIMX  We derive a QA algorithm for clustering and pr...
# 601   OWNX  Experiments show the proposed QA algorithm fin...
# 602   OWNX      Furthermore, QA is as easy as SA to implement
# 604   MISC  Clustering is one of the most popular methods ...
# 605   MISC  Typically, clustering problems are formulated ...
# 606   MISC           However, clustering is typically NP-hard
# 607   MISC  The simulated annealing (SA)  CITATION  is a p...
# 608   MISC  CITATION  proved SA was able to find the globa...
# 609   MISC  Although their schedule is in practice too slo...
# 610   MISC  In statistical mechanics, quantum annealing (Q...
# 611   MISC  QA adds another dimension,  SYMBOL , to SA for...
# 612   MISC         Thus, it can be seen as an extension of SA
# 613   MISC  QA has succeeded in specific problems, e g the...
# 614   OWNX  We do not actually think QA intuitively helps ...
# 615   MISC  A derived QA algorithm depends on the definiti...
# 616   AIMX  We propose quantum effect  SYMBOL , which lead...
# 617   AIMX  Our contribution is, 1) to propose a QA-based ...
# 618   OWNX  We also show the proposed algorithm is as easy...
# 619   OWNX  The algorithm we propose is a Markov chain Mon...
# 620   OWNX  As we explain later, a naive QA sampler is int...
# 621   AIMX  Thus, we approximate QA by the Suzuki-Trotter ...
# 622   BASE  QA-ST looks like parallel  SYMBOL  SAs with in...
# 623   BASE  At the beginning of the annealing process, QA-...
# 624   OWNX  Hence, QA-ST finds  SYMBOL  (local) optima ind...
# 625   OWNX  As the annealing process continues, interactio...
# 626   OWNX  QA-ST at the end picks up the state with the l...
# 627   OWNX  QA-ST with the proposed quantum effect  SYMBOL...
# 628   OWNX  Fig is an example where data points are groupe...
# 629   OWNX  SYMBOL and  SYMBOL are locally optimal and  SY...
# 630   OWNX  Suppose  SYMBOL  is equal to two and  SYMBOL  ...
# 631   OWNX  Although  SYMBOL  and  SYMBOL  are local optim...
# 632   OWNX  Quantum effect  SYMBOL  defines the distance m...
# 633   OWNX  In this case, the proposed  SYMBOL  locates  S...
# 634   OWNX  Thus, the interaction  SYMBOL  gives good chan...
# 635   OWNX  The proposed algorithm actually finds  SYMBOL ...
# 636   OWNX                             Fig is just an example
# 637   MISC  However, a similar situation often occurs in c...
# 638   CONT  Clustering algorithms in most cases give ``alm...
# 639   CONT  Thus, a better clustering assignment can be co...
# 640   CONT  Note an assignment constructed in such a way i...
# 685   AIMX  we introduce a new principle for model selecti...
# 686   MISC  many regression models are controlled by some ...
# 687   OWNX  let   be the  best  regressor of complexity   ...
# 688   MISC  a more flexible regressor can fit more data   ...
# 689   MISC  if something  here small loss  is easy to achi...
# 690   OWNX  we define the loss rank of   as the number of ...
# 691   OWNX  we suggest selecting the model complexity   th...
# 692   MISC  unlike most penalized maximum likelihood varia...
# 693   MISC  it works without a stochastic noise model  and...
# 694   AIMX  in this paper we formalize  discuss  and motiv...
# 696   OWNX  consider a regression or classification proble...
# 697   MISC  one may define regressor   directly  e g    av...
# 698   MISC  if the class   is not too large  e g the polyn...
# 699   MISC  what remains is to select the right model comp...
# 700   MISC  this selection cannot be based on the training...
# 701   OWNX  this problem is called overfitting  for which ...
# 702   MISC  see e g    CITATION  for a comparison of cross...
# 703   MISC  training set based model selection methods all...
# 704   MISC  the most popular ones can be regarded as penal...
# 705   MISC  in addition to the function class    one has t...
# 706   MISC  ml chooses    penalized ml  pml  then chooses ...
# 707   MISC  in particular  modern mdl  CITATION  has sound...
# 708   CONT  all pml variants rely on a proper sampling mod...
# 709   AIMX  the main goal of the paper is to establish a c...
# 710   OWNX  the key observation we exploit is that large c...
# 711   OWNX  we define the  loss rank  of   as the number o...
# 712   MISC  the loss rank is large for regressors fitting ...
# 713   MISC  the loss rank has a minimum for not too flexib...
# 714   OWNX  we claim that minimizing the loss rank is a su...
# 715   CONT  unlike pml  our new loss rank principle  lorp ...
# 716   OWNX  in section   after giving a brief introduction...
# 717   OWNX  to make it applicable to real problems  we hav...
# 718   OWNX  in section  we derive explicit expressions for...
# 719   OWNX  in section  we compare linear lorp to bayesian...
# 720   AIMX  in this paper we just scratch at the surface o...
# 721   OWNX  section  contains further considerations  to b...
# 799   AIMX  we propose a nonparametric bayesian factor reg...
# 800   OWNX  to accomplish this  we propose a sparse varian...
# 801   AIMX  we apply this model to two problems  factor an...
# 803   MISC  factor analysis is the task of explaining data...
# 804   MISC  factor  regression  couples this analysis with...
# 805   MISC  the latent factor representation achieves two ...
# 806   MISC  in particular    NUMBER   is motivated by the ...
# 807   CONT  we address three fundamental shortcomings of s...
# 808   AIMX  our motivation for this work stems from the ta...
# 809   MISC  in this context  factors correspond to regulat...
# 810   AIMX  our contributions thus parallel the needs of g...
# 811   OWNX  in addition  we couple predictive modeling  fo...
# 812   OWNX  our factor regression model is fundamentally n...
# 813   OWNX  in particular  we treat the gene to factor rel...
# 814   OWNX  we  couple  this ibp with a hierarchical prior...
# 815   OWNX  this prior explains the fact that pathways are...
# 816   OWNX  the nonparametric nature of our sparse ibp req...
# 817   BASE  a natural choice is kingman s coalescent  CITA...
# 818   OWNX  since our motivation is an application in bioi...
# 819   OWNX  in particular   genes  are  features    sample...
# 820   CONT                 however  our model is more general
# 821   OWNX  an alternative application might be to a colla...
# 822   OWNX  in this context  all three contributions of ou...
# 824   AIMX  We propose a nonparametric Bayesian factor reg...
# 825   OWNX  To accomplish this, we propose a sparse varian...
# 826   OWNX  We apply this model to two problems (factor an...
# 828   MISC  Factor analysis is the task of explaining data...
# 829   MISC  Factor  regression  couples this analysis with...
# 830   MISC  The latent factor representation achieves two-...
# 831   MISC  In particular, (2) is motivated by the problem...
# 832   AIMX  We address three fundamental shortcomings of s...
# 833   OWNX  Our motivation for this work stems from the ta...
# 834   OWNX  In this context, factors correspond to regulat...
# 835   OWNX  Our contributions thus parallel the needs of g...
# 836   OWNX  In addition, we couple predictive modeling (fo...
# 837   OWNX  Our factor regression model is fundamentally n...
# 838   OWNX  In particular, we treat the gene-to-factor rel...
# 839   OWNX  We  couple  this IBP with a hierarchical prior...
# 840   OWNX  This prior explains the fact that pathways are...
# 841   OWNX  The nonparametric nature of our sparse IBP req...
# 842   BASE  A natural choice is Kingman's coalescent  CITA...
# 843   OWNX  Since our motivation is an application in bioi...
# 844   OWNX  In particular,  genes  are  features ,  sample...
# 845   OWNX                 However, our model is more general
# 846   OWNX  An alternative application might be to a colla...
# 847   OWNX  In this context, all three contributions of ou...
# 874   MISC  in the constraint satisfaction problem      th...
# 875   MISC  in the minimum cost homomorphism problem      ...
# 876   MISC  let   denote the   problem parameterized by th...
# 877   MISC  is related to many well studied combinatorial ...
# 878   AIMX  we show that   can be studied by using algebra...
# 879   OWNX  with the aid of algebraic techniques  we class...
# 880   CONT  our result settles a general dichotomy conject...
# 882   MISC  constraint satisfaction problems     are a nat...
# 883   MISC  this problem has the following two equivalent ...
# 884   MISC  applications of  s arise in the propositional ...
# 885   MISC  during the past  NUMBER  years    and its subp...
# 886   MISC  considerable attention has been given to the c...
# 887   MISC  for example  when   is a constraint language o...
# 888   MISC  this direction of research has been mainly con...
# 889   MISC  it has been shown that the complexity of   is ...
# 890   MISC  for every constraint language    it has been c...
# 891   MISC  in the minimum cost homomorphism problem      ...
# 892   MISC  now  the task is not just to find any satisfyi...
# 893   MISC  was introduced in  CITATION  where it was moti...
# 894   MISC  the question for which directed graphs   the p...
# 895   AIMX  in this paper  we approach the problem in its ...
# 896   OWNX  from this characterization  we obtain a dichot...
# 897   OWNX  of course  this dichotomy implies the dichotom...
# 898   OWNX  in section  NUMBER   we present some prelimina...
# 899   OWNX  the main dichotomy theorem is stated in sectio...
# 900   OWNX  the np hardness results are collected in secti...
# 901   OWNX  section  NUMBER  introduces the concept of  ar...
# 902   OWNX  in section  NUMBER  we reformulate our main re...
# 903   BASE  finally  in section  NUMBER  we explain the re...
# 905   MISC  In the constraint satisfaction problem ( SYMBO...
# 906   MISC  In the minimum cost homomorphism problem ( SYM...
# 907   OWNX  Let  SYMBOL  denote the  SYMBOL  problem param...
# 908   OWNX  SYMBOL  is related to many well-studied combin...
# 909   OWNX  We show that  SYMBOL  can be studied by using ...
# 910   OWNX  With the aid of algebraic techniques, we class...
# 911   AIMX  Our result settles a general dichotomy conject...
# 913   MISC  Constraint satisfaction problems ( SYMBOL ) ar...
# 914   MISC  This problem has the following two equivalent ...
# 915   MISC  Applications of  SYMBOL s arise in the proposi...
# 916   MISC  During the past 30 years,  SYMBOL  and its sub...
# 917   MISC  Considerable attention has been given to the c...
# 918   MISC  For example, when  SYMBOL  is a constraint lan...
# 919   MISC  This direction of research has been mainly con...
# 920   MISC  It has been shown that the complexity of  SYMB...
# 921   MISC  For every constraint language  SYMBOL , it has...
# 922   MISC  In the minimum cost homomorphism problem ( SYM...
# 923   MISC  Now, the task is not just to find any satisfyi...
# 924   MISC  SYMBOL  was introduced in  CITATION  where it ...
# 925   MISC  The question for which directed graphs  SYMBOL...
# 926   AIMX  In this paper, we approach the problem in its ...
# 927   OWNX  From this characterization, we obtain a dichot...
# 928   OWNX  Of course, this dichotomy implies the dichotom...
# 929   OWNX  In Section 2, we present some preliminaries to...
# 930   OWNX  The main dichotomy theorem is stated in Sectio...
# 931   OWNX  The NP-hardness results are collected in Secti...
# 932   OWNX  Section 7 introduces the concept of  arithmeti...
# 933   OWNX  In Section 9 we reformulate our main result in...
# 934   OWNX  Finally, in Section 10 we explain the relation...
# 967   MISC  Regularized risk minimization with the binary ...
# 968   MISC  Bundle methods for regularized risk minimizati...
# 969   MISC  It was recently shown that BMRM requires  SYMB...
# 970   AIMX  In the first part of the paper we use the Hada...
# 971   OWNX  We then show how one can exploit the structure...
# 973   MISC  Let  SYMBOL  denote samples and  SYMBOL  be th...
# 974   MISC  Given a training set of  SYMBOL  sample label ...
# 975   MISC  Here  SYMBOL  denotes the loss on instance  SY...
# 976   MISC  The regularizer  SYMBOL  acts as a penalty on ...
# 977   MISC  Usually the loss is convex in  SYMBOL  but can...
# 978   MISC  Binary Support Vector Machines (SVMs) are a pr...
# 979   MISC  Recently, a number of solvers have been propos...
# 980   MISC  The first and perhaps the best known solver is...
# 981   MISC  The convergence analysis of SVMStruct was impr...
# 982   MISC  In fact,  CITATION  showed that their converge...
# 983   MISC  At every iteration BMRM replaces  SYMBOL  by a...
# 984   MISC  Here  SYMBOL  denotes an arbitrary subgradient...
# 985   MISC  The piecewise linear lower bound is successive...
# 986   CONT  Even though BMRM solves an expensive optimizat...
# 987   CONT  Furthermore, the empirical convergence behavio...
# 988   MISC  It was therefore conjectured that the rates of...
# 989   AIMX  In this paper we answer this question in the n...
# 990   OWNX  One possible way to circumvent the  SYMBOL  lo...
# 991   OWNX  Using a very old result of Nesterov  CITATION ...
# 992   OWNX  Although we primarily focus on the regularized...
# 993   OWNX  Examples of this include multiclass, multi-lab...
# 1051  OWNX  this study was designed to assess sex-related ...
# 1052  OWNX  a simple visuo-spatial task was used to invest...
# 1053  OWNX  the exploration task was followed by a visual ...
# 1054  OWNX  during exploration women selected a local sear...
# 1055  OWNX  women's exploratory behavior gives rise to a n...
# 1056  OWNX  this sex-related difference was interpreted as...
# 1058  MISC  males and females seem to differ in spatial ab...
# 1059  MISC  generally  studies involving navigational prob...
# 1060  MISC  evolutionary mechanisms could potentially acco...
# 1061  MISC  for example  these behavioral differences may ...
# 1062  MISC  mating patterns or mating strategies are linke...
# 1063  MISC  typically  males have to compete through exten...
# 1064  MISC  another proposition  but exclusively directed ...
# 1065  MISC  however  as argued by ecuyer-dab and robert  C...
# 1066  MISC  in females  however  spatial cognition would h...
# 1067  MISC  this concern would have compelled them to favo...
# 1068  MISC  such focusing would have enabled secure naviga...
# 1069  MISC  thus  the hypothesis of labor division would b...
# 1070  MISC  taken together  the literature seems to indica...
# 1071  MISC  in that context spatial skills play a crucial ...
# 1072  MISC  hence  the survival of mobile species depends ...
# 1073  CONT  experimental investigations of sex differences...
# 1074  MISC  this might be partly due to the complexity of ...
# 1075  OWNX  the current study investigates sex differences...
# 1076  OWNX  following the above quotation from ecuyer-dab ...
# 1077  OWNX  to test this  i used a simple spontaneous two-...
# 1078  OWNX  this choice relies on the fact that exploratio...
# 1079  MISC  it seems to be based on driving factors such a...
# 1080  MISC  moreover  it is commonly defined as serving to...
# 1081  MISC  exploration is mainly characterized by a succe...
# 1082  MISC  indeed  progressions are based on decisions ta...
# 1083  MISC  voss  CITATION  refers to the exploration proc...
# 1084  OWNX  in order to assess risk-taking  a classical vi...
# 1085  OWNX  the results were analyzed with signal detectio...
# 1159  MISC  similar to research on risky choice, the tradi...
# 1160  MISC  the well-known allais paradox contradicts the ...
# 1161  AIMX  we describe a violation of the law of diminish...
# 1163  MISC  in the field of intertemporal choice, the disc...
# 1164  MISC  in its general form, the du theory proposes th...
# 1165  MISC  the overall value of a mixed option, a = {x, t...
# 1166  MISC                         that is, va = sigma  ux ft
# 1167  MISC  an option a will be preferred to an option b i...
# 1168  MISC  however, a large body of empirical evidence de...
# 1169  MISC  this includes the common difference effect, th...
# 1170  MISC  this situation has led researchers to consider...
# 1171  MISC  the most prominent idea to account for these a...
# 1172  MISC  this model suggests that the discount rate is ...
# 1173  MISC  numerous theories have been developed by trans...
# 1174  MISC  however, these models focus on intertemporal c...
# 1175  MISC  when these models are applied to intertemporal...
# 1176  MISC  with an apt transformation of the discounting ...
# 1177  MISC  the independence assumption means that the val...
# 1178  MISC  because risk and delay might be psychologicall...
# 1179  MISC  both lines of research have spawned a large nu...
# 1180  MISC  although the functional forms differ, most the...
# 1181  CONT  a minor difference is that the existing models...
# 1182  CONT  for example, research on risky decision making...
# 1183  CONT  examples include the sign-dependent utility mo...
# 1184  MISC  the well-known allais paradox  CITATION  contr...
# 1185  MISC  the paradox presents a violation of the cancel...
# 1186  MISC  since then, many new descriptive theories of r...
# 1187  MISC  most models of intertemporal choice have not y...
# 1188  MISC  these two assumptions would lead to the cancel...
# 1189  MISC  table 1 illustrates an example of the multiple...
# 1190  MISC  in problem i, the additive models predict that...
# 1191  MISC  the violation of cancellation would be observe...
# 1192  MISC  however, if allais's proposition applies to in...
# 1193  AIMX  we first illustrate our point with a paradox t...
# 1267  AIMX  the paper extends research on fixed-pie percep...
# 1268  OWNX  we test our predictions using data on israeli ...
# 1269  OWNX  the results demonstrate that israelis are more...
# 1270  OWNX  we show that implementation concerns create a ...
# 1271  OWNX  the effect of balance is noteworthy in that it...
# 1273  MISC  normative models of bargaining and negotiation...
# 1274  CONT  descriptive accounts and empirical investigati...
# 1275  MISC  for example, research on cognitive biases asso...
# 1276  MISC  the fixed-pie bias refers to the belief that a...
# 1277  MISC  this belief is a "bias" when it persists even ...
# 1278  MISC  a large body of research finds that negotiator...
# 1279  BASE  in the current paper we investigate and extend...
# 1281  AIMX  the paper extends research on fixed-pie percep...
# 1282  OWNX  we test our predictions using data on israeli ...
# 1283  OWNX  the results demonstrate that israelis are more...
# 1284  AIMX  we show that implementation concerns create a ...
# 1285  OWNX  the effect of balance is noteworthy in that it...
# 1287  MISC  normative models of bargaining and negotiation...
# 1288  CONT  descriptive accounts and empirical investigati...
# 1289  MISC  for example, research on cognitive biases asso...
# 1290  MISC  the fixed-pie bias refers to the belief that a...
# 1291  CONT  this belief is a "bias" when it persists even ...
# 1292  MISC  a large body of research finds that negotiator...
# 1293  AIMX  in the current paper we investigate and extend...
# 1309  AIMX  we test in the context of a dictator game the ...
# 1310  OWNX  we manipulated the likelihood that individuals...
# 1311  OWNX  our analysis reveals a positive and significan...
# 1312  OWNX  the magnitude of the effect is of economic sig...
# 1313  OWNX  we conclude that subtle cues might prove suffi...
# 1315  MISC  lured by temptation, individuals may find them...
# 1316  MISC  self-control failure, famously termed akrasia ...
# 1317  MISC  for example, the dieter faced with the opportu...
# 1318  MISC  the student may feel conflicted between the de...
# 1319  MISC  and, similarly, the fashionista might feel con...
# 1320  MISC  perhaps less intuitively, but no less importan...
# 1321  MISC  this conceptualization may help reconcile conf...
# 1322  MISC  that individuals should care much about their ...
# 1323  MISC  for example, many individuals voluntarily cont...
# 1324  MISC  nonetheless, one could imagine that even indiv...
# 1325  MISC  that is, pro-social preferences potentially fl...
# 1326  MISC  self-control-our capacity to overrule temptati...
# 1327  MISC  a multitude of conceptualizations exist, many ...
# 1328  MISC  typically, and in line with classic ideas of t...
# 1329  MISC  willpower, then, represents the combined resou...
# 1330  MISC  such resources may include cognitive strategie...
# 1331  MISC  our conceptualization of self-control mirrors ...
# 1332  MISC  only recently has the psychological literature...
# 1333  MISC  loewenstein  CITATION  suggests that selfish b...
# 1334  MISC  o'donoghue and loewenstein  CITATION  argue th...
# 1335  CONT  at present, there is but indirect evidence for...
# 1336  MISC  for example, pronin et al CITATION  show that ...
# 1337  MISC  albrecht et al CITATION  report consistent res...
# 1338  MISC  moreover, curry et al CITATION  find in a stan...
# 1339  MISC  that is, more "impatient" individuals contribu...
# 1340  MISC  arriving at similar results, fehr and leibbran...
# 1341  MISC  furthermore, burks et al CITATION  find that "...
# 1342  MISC  however, duffy and smith  CITATION  report no ...
# 1343  MISC  an emerging literature on the "default" respon...
# 1344  MISC  achtziger et al CITATION  subjected players in...
# 1345  MISC  moreover, depleted responders were more likely...
# 1346  MISC  halali et al CITATION  report the same for res...
# 1347  MISC  crockett et al CITATION  subjected responders ...
# 1348  MISC  using a trust game, knoch et al CITATION  subj...
# 1349  MISC  trustees, though cognizant that returning a sh...
# 1350  MISC  closest to our domain of inquiry, piovesan and...
# 1351  MISC  they find both across and within participants ...
# 1352  MISC  one interpretation of their results is that th...
# 1353  MISC  such successful resolution of conflict would r...
# 1354  AIMX  in this paper we attempt a more direct test of...
# 1355  OWNX  we employ a standard measure of pure pro-socia...
# 1356  OWNX  further, we explore the conditions under which...
# 1357  BASE  in so doing, we rely on two conditions necessa...
# 1358  MISC  critically, self-control strategies are releva...
# 1359  MISC  therefore, one strategy for investigating whet...
# 1360  MISC  determinants of conflict identification in the...
# 1361  MISC  in some contexts, the question is almost trivi...
# 1362  MISC  for example, the diabetic dieter probably know...
# 1363  MISC  however, the question of self-control conflict...
# 1364  MISC  having this one chocolate alone will not incur...
# 1365  MISC  similarly, the good citizen may find that a ge...
# 1366  MISC  myrseth and fishbach  CITATION  use the term e...
# 1367  MISC  they argue that individuals identify self-cont...
# 1368  MISC  that is, considering the question of whether o...
# 1369  MISC  similarly, the question of whether or not to b...
# 1370  MISC  if viewed in relation to future decisions, the...
# 1371  MISC  however, if viewed in isolation, the question ...
# 1372  MISC  because a consistent self-image represents an ...
# 1373  MISC  myrseth and fishbach  CITATION  show that subt...
# 1374  MISC  they find that presenting a calendar displayin...
# 1375  MISC  they argue that the gridded calendar activated...
# 1376  MISC  consequently, the grid reduced the likelihood ...
# 1377  MISC  indeed, participants who viewed the gridded ca...
# 1378  MISC  furthermore, participants' trait ability to im...
# 1379  MISC  that is, participants who viewed the calendar ...
# 1380  OWNX  to explore our hypothesis that the problem of ...
# 1381  OWNX  the game thus pits pro-social motivations agai...
# 1382  OWNX  if pro-social versus selfish behavior could re...
# 1383  OWNX  the graph in figure 2 displays donation, as a ...
# 1384  OWNX  in the case of low likelihood, the slope is ex...
# 1385  OWNX  in the case of the higher likelihood, however,...
# 1386  OWNX  this means that for a given level of self-cont...
# 1594  MISC  previous tests of cumulative prospect theory c...
# 1595  CONT  however, those tests were criticized because t...
# 1596  AIMX  this paper presents new tests that avoid those...
# 1597  OWNX  expected values of the gambles are nearly equa...
# 1598  OWNX  in addition, if a person followed expected val...
# 1599  OWNX  in contrast, the transfer of attention exchang...
# 1600  OWNX  results contradict the ph, even when ph is mod...
# 1601  OWNX  new tests of probability-consequence interacti...
# 1602  OWNX  strong interactions were observed, contrary to ph
# 1603  OWNX  these results add to the growing bodies of evi...
# 1605  AIMX  this paper compares three models that attempt ...
# 1606  AIMX  these models are cumulative prospect theory cp...
# 1607  MISC  the ph model is based on the idea that people ...
# 1608  BASE  in addition, the similarity model of rubinstei...
# 1609  MISC  birnbaum  CITATION  reviewed a number of criti...
# 1610  MISC  birnbaum  CITATION  noted that many of the sam...
# 1611  MISC  for example, the priority heuristic predicted ...
# 1612  MISC  some of these choices included cases where 90%...
# 1613  MISC  in other choices, significantly more than half...
# 1614  MISC  brandstatter, gigerenzer, and hertwig  CITATIO...
# 1615  MISC   presumably, decision makers first decide what...
# 1616  CONT  the mechanism that decides what rule to use ha...
# 1617  MISC  brandstatter et al CITATION  concluded that th...
# 1618  MISC  in addition, brandstatter et al CITATION  argu...
# 1619  CONT  brandstatter et al CITATION  presented a figur...
# 1620  MISC  from the data, brandstatter et al CITATION  es...
# 1621  MISC  brandstatter et al consider ev ratio as a prox...
# 1622  MISC  they argued that the priority heuristic is acc...
# 1623  CONT  however, birnbaum  CITATION  noted that ev rat...
# 1624  MISC  brandstatter et al CITATION  replicated part o...
# 1625  MISC  to account for the results, brandstatter et al...
# 1626  CONT  ph was not accurate for such choices, so brand...
# 1627  MISC  in some of the choices in birnbaum and navarre...
# 1628  CONT  the arguments of brandstatter et al CITATION  ...
# 1629  AIMX  this paper devises a new type of test that avo...
# 1630  OWNX  in these tests, one alternative does not stoch...
# 1631  CONT  in addition, unlike previous tests, the new te...
# 1632  OWNX  that is, expected value and expected utility a...
# 1633  OWNX  however, the choices are designed so that the ...
# 1635  MISC  previous tests of cumulative prospect theory c...
# 1636  CONT  however, those tests were criticized because t...
# 1637  AIMX  this paper presents new tests that avoid those...
# 1638  OWNX  expected values of the gambles are nearly equa...
# 1639  OWNX  in addition, if a person followed expected val...
# 1640  OWNX  in contrast, the transfer of attention exchang...
# 1641  OWNX  results contradict the ph, even when ph is mod...
# 1642  OWNX  new tests of probability-consequence interacti...
# 1643  OWNX  strong interactions were observed, contrary to ph
# 1644  OWNX  these results add to the growing bodies of evi...
# 1646  AIMX  this paper compares three models that attempt ...
# 1647  AIMX  these models are cumulative prospect theory cp...
# 1648  MISC  the ph model is based on the idea that people ...
# 1649  BASE  in addition, the similarity model of rubinstei...
# 1650  MISC  birnbaum  CITATION  reviewed a number of criti...
# 1651  MISC  birnbaum  CITATION  noted that many of the sam...
# 1652  MISC  for example, the priority heuristic predicted ...
# 1653  MISC  some of these choices included cases where 90%...
# 1654  MISC  in other choices, significantly more than half...
# 1655  MISC  brandstatter, gigerenzer, and hertwig  CITATIO...
# 1656  MISC   presumably, decision makers first decide what...
# 1657  CONT  the mechanism that decides what rule to use ha...
# 1658  MISC  brandstatter et al CITATION  concluded that th...
# 1659  MISC  in addition, brandstatter et al CITATION  argu...
# 1660  CONT  brandstatter et al CITATION  presented a figur...
# 1661  MISC  from the data, brandstatter et al CITATION  es...
# 1662  MISC  brandstatter et al consider ev ratio as a prox...
# 1663  MISC  they argued that the priority heuristic is acc...
# ...
# 2749  MISC  The hippocampus and surrounding medial tempora...
# 2750  MISC  Electrophysiology studies in a range of specie...
# 2751  MISC  The majority of empirical investigation has fo...
# 2752  MISC  Subsequent research has identified similar sin...
# 2753  MISC  It has also been demonstrated that the exact t...
# 2754  MISC  This phase precession mechanism creates a comp...
# 2755  MISC  These findings have led to the hypothesis that...
# 2756  OWNX  Here we present a spiking neural network model...
# 2757  MISC  The postulated mnemonic function of the hippoc...
# 2758  MISC  The biological correlate of these models is wi...
# 2759  MISC  Pharmacological and genetic knockout studies h...
# 2760  MISC  Recurrent neural network models of hippocampal...
# 2761  MISC  Hypothetically, this corresponds to the presen...
# 2762  MISC  The hippocampus is also implicated in sequence...
# 2763  MISC  Hypothetically, this corresponds to a sequence...
# 2764  MISC  Importantly, previous computational models of ...
# 2765  CONT  No computational model has thus far integrated...
# 2766  MISC  Empirical data indicates that changes in the s...
# 2767  MISC  It is not yet clear if rate-coded auto-associa...
# 2768  AIMX  Here, we examine the synaptic dynamics generat...
# 2769  OWNX  We demonstrate that under certain conditions -...
# 2770  OWNX  Subsequent superthreshold stimulation of a sma...
# 2771  OWNX  Interestingly, these neural dynamics are remin...
# 2772  OWNX  These findings demonstrate that STDP and theta...
# 2773  OWNX  Furthermore, the encoding and reactivation of ...
# 2852  MISC  Metabolic network reconstructions represent va...
# 2853  MISC  However, they do not explicitly account for th...
# 2854  OWNX  Here, we present the first genome-scale, fine-...
# 2855  BASE  Legacy data from over 500 publications and thr...
# 2856  OWNX  This reconstruction represents the most compre...
# 2857  OWNX  Furthermore, it was converted into a mathemati...
# 2858  OWNX  For example, the model predicted accurately th...
# 2859  OWNX  Also, in silico rRNA operon deletion suggested...
# 2860  OWNX  Moreover, functional protein modules were dete...
# 2861  OWNX  This genome-scale reconstruction of E. coli's ...
# 2863  MISC  High-throughput experimental technologies enab...
# 2864  MISC  A detailed mathematical representation of the ...
# 2865  MISC  One such approach is the bottom-up network rec...
# 2866  MISC  This reconstruction procedure is well establis...
# 2867  MISC  These bottom-up metabolic networks differ from...
# 2868  MISC  Hence, these reconstructions can be thought of...
# 2869  MISC  The reconstruction and modeling procedure is a...
# 2870  MISC  By iterating step 2 to 4, reconstructions that...
# 2871  MISC  Metabolic network reconstruction have demonstr...
# 2872  MISC  This wide range of applications of the metabol...
# 2873  MISC  Unlike more traditional approaches to modeling...
# 2874  MISC  The stoichiometric information encoded in the ...
# 2875  MISC  While the COBRA approach has been successfully...
# 2876  BASE  In this study, we extended and refined earlier...
# 2877  OWNX  We created a more detailed, gene-specific repr...
# 2878  OWNX  This reconstruction enables quantitative integ...
# 2879  OWNX  Moreover, proteins are produced in high copy n...
# 2880  MISC  Numerous studies have been published that inve...
# 2881  CONT  These models are generally tailored to the que...
# 2882  MISC  Since stoichiometric relationships are a commo...
# 2883  MISC  In fact, network stoichiometry is a dominant f...
# 2884  MISC  Thus, network reconstruction serves as a platf...
# 2885  AIMX  In this study, we present a new generation of ...
# 2886  OWNX  We named the mathematical representation of th...
# 2887  OWNX  All network reactions were formulated to accou...
# 2888  OWNX  Furthermore, we used information from three da...
# 2889  OWNX  This reconstruction is the first comprehensive...
# 2890  OWNX  After conversion of the E-matrix reconstructio...
# 2891  OWNX  Furthermore, we show that the E-matrix can be ...
# 2892  OWNX  Our results predict that a high density of RNA...
# 2893  OWNX  Finally, we show that proteins used in the E-m...
# 2976  MISC  Neuronal activity is mediated through changes ...
# 2977  MISC  While differences in morphology define neurona...
# 2978  AIMX  We introduce and validate new computational to...
# 2979  OWNX  Comparison of five morphologically distinct ne...
# 2980  OWNX  For typical neurons, the amplitude of membrane...
# 2981  OWNX  Using a detailed model of a hippocampal CA1 py...
# 2982  OWNX  At physiological firing rates, stochastic gati...
# 2983  OWNX  These results suggest that the consequences of...
# 2984  OWNX  Whereas dendritic neurons are often assumed to...
# 2986  MISC  The appropriate level of physical detail requi...
# 2987  CONT  For example, while it is possible to account f...
# 2988  MISC  Dendritic and axonal morphology are defining f...
# 2989  MISC  Differences in morphology determine how neuron...
# 2990  BASE  Cable theory and compartmental modeling provid...
# 2991  MISC  However, while the assumption that transitions...
# 2992  MISC  Stochastic opening and closing of ion channels...
# 2993  CONT  While cable theory suggests that fluctuations ...
# 2994  MISC  Given the difficulty of reducing detailed morp...
# 2995  CONT  Investigation of stochastic ion channel gating...
# 2996  MISC  A simple approach is to add noise sources to d...
# 2997  CONT  However, as ion channels have multiple functio...
# 2998  MISC  A more accurate alternative is to explicitly m...
# 2999  CONT  However, for neurons with complex axonal or de...
# 3000  CONT  First, typical central neurons express large n...
# 3001  CONT  This is a formidable computational task and ev...
# 3002  CONT  Second, each neuronal ion channel occupies a s...
# 3003  CONT  Although this formalism has been successful fo...
# 3004  AIMX  To address the functional consequences of stoc...
# 3005  OWNX  We have also developed an interactive tool for...
# 3006  OWNX  Here, we illustrate the use of PSICS and ICING...
# 3007  OWNX  We then identify previously unappreciated diff...
# 3008  OWNX  We show that the consequences of stochastic ga...
# 3009  BASE  Using a previously well-validated realistic mo...
# 3010  OWNX  We show that stochastic gating of axonal or de...
# 3011  OWNX  By demonstrating that neuronal responses to de...
# 3012  OWNX  Full documentation for PSICS/ICING as well as ...
# 3052  MISC  Alternative splicing contributes to both gene ...
# 3053  AIMX  To discover broad relationships between regula...
# 3054  OWNX  In a set of 22 adult tissues, we observe diffe...
# 3055  OWNX  Statistical comparisons identify 171 cassette ...
# 3056  OWNX  A subset of these exons is associated with unu...
# 3057  OWNX  By focusing on sets of exons with similar regu...
# 3058  OWNX  Of note is a motif that is strikingly similar ...
# 3059  OWNX  Analysis of three paralogous membrane-associat...
# 3060  OWNX  While the intron sequences flanking these exon...
# 3062  MISC  Splicing is an essential process that construc...
# 3063  MISC  Regulated alternative splicing can create diff...
# 3064  MISC  In addition, alternative splicing can mediate ...
# 3065  MISC  Splicing patterns seem distinct in the vertebr...
# 3066  MISC  Biochemical analysis of alternative splicing h...
# 3067  MISC  These RNA binding proteins may activate or rep...
# 3068  MISC  In many cases, multiple RNA binding proteins c...
# 3069  MISC  Some proteins, such as SR proteins and the CEL...
# 3070  MISC  Certain proteins can either activate or repres...
# 3071  MISC  A complete catalog of the RNA sequences corres...
# 3072  MISC  Thus far, there are only a handful of splicing...
# 3073  MISC  In addition, several related but distinct gene...
# 3074  MISC  Adding to this complexity is the tendency for ...
# 3075  CONT  Currently, the methods available for expanding...
# 3076  MISC  Much of the available genomic information on a...
# 3077  MISC  The analysis of exons that appear to be consti...
# 3078  CONT  Although cDNA libraries have been invaluable f...
# 3079  CONT  The relatively low number of transcripts prese...
# 3080  MISC  Thus, more direct methods are needed to associ...
# 3081  MISC  The recent application of microarray technolog...
# 3082  MISC  Analysis of experimental changes in splicing f...
# 3083  OWNX  To demonstrate this, we constructed a DNA micr...
# 3084  AIMX  We examine splicing in these tissues by asking...
# 3085  OWNX  First we ask, Which RNA isoforms are present i...
# 3086  OWNX  To answer this simple question, we used a new ...
# 3087  BASE  This is similar in spirit although different i...
# 3088  OWNX  Using RT-PCR, we show that this method has a t...
# 3089  OWNX  Second we ask, Which RNA isoforms are differen...
# 3090  BASE  For each RNA isoform, the intensities of the i...
# 3091  OWNX  After correcting for multiple testing, about 4...
# 3092  OWNX  Third we ask, Which cassette exons are include...
# 3093  OWNX  To answer this, we used a regression-based boo...
# 3094  OWNX  We analyzed the intron sequences associated wi...
# 3096  MISC  Alternative splicing contributes to both gene ...
# 3097  AIMX  To discover broad relationships between regula...
# 3098  OWNX  In a set of 22 adult tissues, we observe diffe...
# 3099  OWNX  Statistical comparisons identify 171 cassette ...
# 3100  OWNX  A subset of these exons is associated with unu...
# 3101  OWNX  By focusing on sets of exons with similar regu...
# 3102  OWNX  Of note is a motif that is strikingly similar ...
# 3103  OWNX  Analysis of three paralogous membrane-associat...
# 3104  OWNX  While the intron sequences flanking these exon...
# 3106  MISC  Splicing is an essential process that construc...
# 3107  MISC  Regulated alternative splicing can create diff...
# 3108  MISC  In addition, alternative splicing can mediate ...
# 3109  MISC  Splicing patterns seem distinct in the vertebr...
# 3110  MISC  Biochemical analysis of alternative splicing h...
# 3111  MISC  These RNA binding proteins may activate or rep...
# 3112  MISC  In many cases, multiple RNA binding proteins c...
# 3113  MISC  Some proteins, such as SR proteins and the CEL...
# 3114  MISC  Certain proteins can either activate or repres...
# 3115  MISC  A complete catalog of the RNA sequences corres...
# 3116  MISC  Thus far, there are only a handful of splicing...
# 3117  MISC  In addition, several related but distinct gene...
# 3118  MISC  Adding to this complexity is the tendency for ...
# 3119  CONT  Currently, the methods available for expanding...
# 3120  MISC  Much of the available genomic information on a...
# 3121  MISC  The analysis of exons that appear to be consti...
# 3122  CONT  Although cDNA libraries have been invaluable f...
# 3123  CONT  The relatively low number of transcripts prese...
# 3124  MISC  Thus, more direct methods are needed to associ...
# 3125  MISC  The recent application of microarray technolog...
# 3126  MISC  Analysis of experimental changes in splicing f...
# 3127  OWNX  To demonstrate this, we constructed a DNA micr...
# 3128  AIMX  We examine splicing in these tissues by asking...
# 3129  OWNX  First we ask, Which RNA isoforms are present i...
# 3130  OWNX  To answer this simple question, we used a new ...
# 3131  BASE  This is similar in spirit although different i...
# 3132  OWNX  Using RT-PCR, we show that this method has a t...
# 3133  OWNX  Second we ask, Which RNA isoforms are differen...
# 3134  BASE  For each RNA isoform, the intensities of the i...
# 3135  OWNX  After correcting for multiple testing, about 4...
# 3136  OWNX  Third we ask, Which cassette exons are include...
# 3137  OWNX  To answer this, we used a regression-based boo...
# 3138  OWNX  We analyzed the intron sequences associated wi...
# 3184  MISC  Human Immunodeficiency Virus 1 uses for entry ...
# 3185  MISC  Recently, a new class of antiretroviral drugs ...
# 3186  MISC  Accurate prediction of the co-receptor used by...
# 3187  AIMX  We have investigated whether it is possible to...
# 3188  OWNX  We developed a two-level machine learning appr...
# 3189  OWNX  The second level combines the two predictions ...
# 3190  OWNX  The two-level method predicts usage of CXCR4 c...
# 3191  OWNX  Moreover, it is relatively robust against inse...
# 3192  OWNX  The approach could help clinicians to find opt...
# 3193  OWNX  For instance, it quantifies the importance for...
# 3195  MISC  Specific protein interactions are central to b...
# 3196  MISC  In the case of pathogenic viruses, such protei...
# 3197  MISC  An example of particularly high relevance is H...
# 3198  MISC  HIV-1 enters human cells in a process that com...
# 3199  MISC  The type of co-receptor used by the virus, the...
# 3200  MISC  In addition to the purely X4- and R5-tropic vi...
# 3201  MISC  Recently, the first drug that binds to CCR5, a...
# 3202  MISC  This has made the determination of co-receptor...
# 3203  MISC  The standard way of determining co-receptor tr...
# 3204  CONT  The main drawbacks of these assays are that th...
# 3205  MISC  These impediments to the wide application of e...
# 3206  MISC  This is a relatively fast and cheap standard p...
# 3207  MISC  At first glance, genotypic testing for co-rece...
# 3208  CONT  Unfortunately, as suggested by its name, V3 is...
# 3209  MISC  Nevertheless, the relevance of the quest has p...
# 3210  MISC  The importance of electrostatics for co-recept...
# 3211  MISC  This rule has a specificity of more than 0.9, ...
# 3212  MISC  To improve predictions from sequence, several ...
# 3213  CONT  Still, prediction accuracies fall short of wha...
# 3214  MISC  It is unclear whether the limited accuracies a...
# 3215  MISC  A milestone for the understanding of co-recept...
# 3216  MISC  This paved the way for the development of pred...
# 3217  MISC  To our knowledge, the first of these methods h...
# 3218  BASE  Although our method, detailed in the following...
# 3219  OWNX  By the latter we consider a seemingly trivial ...
# 3220  OWNX  The accuracy of the method makes it attractive...
# 3222  MISC  Human Immunodeficiency Virus 1 uses for entry ...
# 3223  MISC  Recently, a new class of antiretroviral drugs ...
# 3224  MISC  Accurate prediction of the co-receptor used by...
# 3225  AIMX  We have investigated whether it is possible to...
# 3226  OWNX  We developed a two-level machine learning appr...
# 3227  OWNX  The second level combines the two predictions ...
# 3228  OWNX  The two-level method predicts usage of CXCR4 c...
# 3229  OWNX  Moreover, it is relatively robust against inse...
# 3230  OWNX  The approach could help clinicians to find opt...
# 3231  OWNX  For instance, it quantifies the importance for...
# 3233  MISC  Specific protein interactions are central to b...
# 3234  MISC  In the case of pathogenic viruses, such protei...
# 3235  MISC  An example of particularly high relevance is H...
# 3236  MISC  HIV-1 enters human cells in a process that com...
# 3237  MISC  The type of co-receptor used by the virus, the...
# 3238  MISC  In addition to the purely X4- and R5-tropic vi...
# 3239  MISC  Recently, the first drug that binds to CCR5, a...
# 3240  MISC  This has made the determination of co-receptor...
# 3241  MISC  The standard way of determining co-receptor tr...
# 3242  CONT  The main drawbacks of these assays are that th...
# 3243  MISC  These impediments to the wide application of e...
# 3244  MISC  This is a relatively fast and cheap standard p...
# 3245  MISC  At first glance, genotypic testing for co-rece...
# 3246  CONT  Unfortunately, as suggested by its name, V3 is...
# 3247  MISC  Nevertheless, the relevance of the quest has p...
# 3248  MISC  The importance of electrostatics for co-recept...
# 3249  MISC  This rule has a specificity of more than 0.9, ...
# 3250  MISC  To improve predictions from sequence, several ...
# 3251  CONT  Still, prediction accuracies fall short of wha...
# 3252  MISC  It is unclear whether the limited accuracies a...
# 3253  MISC  A milestone for the understanding of co-recept...
# 3254  MISC  This paved the way for the development of pred...
# 3255  MISC  To our knowledge, the first of these methods h...
# 3256  BASE  Although our method, detailed in the following...
# 3257  OWNX  By the latter we consider a seemingly trivial ...
# 3258  OWNX  The accuracy of the method makes it attractive...

# %%
import re                         # regex for preprocessing text
import numpy as np
from collections import Counter
print(Counter(df["label"]))       # the number of sentences for each label

# preprocessing the data
def clean_data(text):
    text = re.sub(r"\n", "", text)    
    text = re.sub(r"\r", "", text) 
    text = re.sub(r"\'", "", text)    
    text = re.sub(r"\"", "", text)
    return text.strip().lower()
# Out:
# Counter({'MISC': 852, 'OWNX': 427, 'CONT': 104, 'AIMX': 94, 'BASE': 33})

# %%
# load stopwords from stopwords.txt
file_stopwords = open("E:\STUDY\Placements\dishQ\SentenceCorpus\word_lists/stopwords.txt","r")
stopwords = []
for w in file_stopwords:
    if w.endswith('\n'):
        w = w[:-1]
        stopwords.append(w)

# %%
df.iloc[:8]
# Out:
#   label                                           sentence
# 1  MISC  The Minimum Description Length principle for o...
# 2  MISC  If the underlying model class is discrete, the...
# 3  MISC  For MDL, in general one can only have loss bou...
# 4  AIMX  We show that this is even the case if the mode...
# 5  OWNX  We derive a new upper bound on the prediction ...
# 6  OWNX  This implies a small bound (comparable to the ...
# 7  OWNX  We discuss the application to Machine Learning...
# 9  MISC  ``Bayes mixture", ``Solomonoff induction", ``m...

# %%
# train test split
from sklearn.model_selection import train_test_split
# X - text data (Sentences)
# y - labels
X = []
for i in range(len(df)):
    X.append(clean_data(df.iloc[i][1]))
y = np.array(df["label"])
X = np.array(X)

# set any specific random seed to get reproducible results
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.svm import LinearSVC
from sklearn.multiclass import OneVsRestClassifier
from sklearn.pipeline import Pipeline

model = Pipeline([('vectorizer', CountVectorizer()),('tfidf', TfidfTransformer()),
 ('clf', OneVsRestClassifier(LinearSVC(class_weight="balanced")))])

# %%
#paramater selection
from sklearn.grid_search import GridSearchCV
parameters = {'vectorizer__ngram_range': [(1, 1), (1, 2),(2,2)],
              'vectorizer__stop_words': (None,'english',stopwords),
               'tfidf__use_idf': (True, False)}
gs_clf_svm = GridSearchCV(model, parameters)
gs_clf_svm = gs_clf_svm.fit(X, y)
print(gs_clf_svm.best_params_)
# Out:
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# {'vectorizer__ngram_range': (1, 2), 'vectorizer__stop_words': ['of', 'a', 'and', 'the', 'in', 'to', 'for', 'that', 'is', 'on', 'are', 'with', 'as', 'by', 'be', 'an', 'which', 'it', 'from', 'or', 'can', 'have', 'these', 'has', 'such'], 'tfidf__use_idf': False}
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
#the final pipeline using the best parameters
model = Pipeline([('vectorizer', CountVectorizer(stop_words=stopwords,ngram_range=(1,2))),
    ('tfidf', TfidfTransformer(use_idf=False)),
    ('clf', OneVsRestClassifier(LinearSVC(class_weight="balanced")))])

# %%
#fit model with training data
model.fit(X_train, y_train)
# Out:
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# Pipeline(memory=None,
#      steps=[('vectorizer', CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), preprocessor=None,
#         stop_words=['of'...lti_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0),
#           n_jobs=1))])

# %%
# vocab of the model
vocab = model.named_steps['vectorizer'].vocabulary_

#test data evaluation
pred = model.predict(X_test)

# compare predicted data with actual test data 
from sklearn.metrics import confusion_matrix, accuracy_score
confusion_matrix(pred, y_test)
# Out:
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# array([[  9,   0,   0,   0,   5],
#        [  1,   1,   0,   2,   0],
#        [  0,   2,   7,   1,   2],
#        [  2,   0,   9, 147,  14],
#        [  7,   3,   3,  15,  72]], dtype=int64)

# %%
model.classes_
# Out:
# array(['AIMX', 'BASE', 'CONT', 'MISC', 'OWNX'], dtype='<U4')

# %%
accuracy_score(y_test, pred)
# Out:
# 0.7814569536423841

# %%
#save the model
from sklearn.externals import joblib
joblib.dump(model, 'E:\STUDY\Placements\dishQ\SentenceCorpus/SentClassificationModel.pkl')
# Out:
# ['E:\\STUDY\\Placements\\dishQ\\SentenceCorpus/SentClassificationModel.pkl']

# %%
from sklearn.externals import joblib
model = joblib.load('SentClassificationModel.pkl')

# %%
# ask a sentence from test files
sentence = input()

# %%
model.predict([sentence])[0]
# Out:
# c:\users\varad bhogayata\appdata\local\programs\python\python35\lib\site-packages\sklearn\feature_extraction\text.py:1089: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):
# 'OWNX'
